# %% [markdown]
# ## Visualización de datos

# %%
! pip install matplotlib

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5, 6, 7]
y = [4, 3, 6, 5, 9, 7, 1]

plt.plot(x, y)

plt.show() # plt.savefig("mi-grafica.png")

# %%
import matplotlib.pyplot as plt

x1 = [1, 2, 3, 4, 5, 6]
y1 = [6, 5, 3, 7, 6, 8]

plt.plot(x1, y1)

x2 = [1, 3, 5, 7, 9]
y2 = [4, 3, 2, 7, 6]

plt.plot(x2, y2)

plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5, 6]
y = [4, 3, 5, 2, 3, 1]

plt.plot(x, y, color="#d5b0ff")

plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5, 6]
y = [4, 3, 5, 2, 3, 1]

plt.plot(x, y, marker="o")

plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5, 6]
y = [4, 3, 5, 2, 3, 1]

plt.plot(x, y, marker="s")

plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5, 6]
y = [4, 3, 5, 2, 3, 1]

plt.plot(x, y, marker="^")

plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5, 6]
y = [4, 3, 5, 2, 3, 1]

plt.plot(x, y, marker="*")

plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5, 6]
y = [4, 3, 5, 2, 3, 1]

plt.plot(x, y, "o--") # marcador punto más línea punteada

plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5, 6]
y = [4, 3, 5, 2, 3, 1]

plt.plot(x, y, "o-") # marcador punto más línea continua

plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5, 6]
y = [4, 3, 5, 2, 3, 1]

plt.plot(x, y, "o") # marcador punto sin línea

plt.show()

# %%
import matplotlib.pyplot as plt

x1 = [1, 2, 3, 4, 5, 6]
y1 = [4, 3, 5, 2, 3, 1]

x2 = [1, 2, 3, 4, 5, 6]
y2 = [3, 7, 3, 2, 1, 2]

x3 = [1, 2, 3, 4, 5, 6]
y3 = [3, 4, 6, 2, 2, 3]

plt.plot(x1, y1, "s-", color="red")
plt.plot(x2, y2, "o--", color="blue", lw=3) # lw <-> linewidth
plt.plot(x3, y3, "s", color="gray", ms=10, mfc="magenta")

# https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.plot.html

plt.show()
