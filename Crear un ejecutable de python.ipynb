# %% [markdown]
# # Crear un ejecutable de un programa de python

# %% [markdown]
# 1. Crear un archivo `graficador.py` con el programa de python (el código completo)

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3]
y = [4, 5, 6]

plt.plot(x, y)

plt.show()

# %% [markdown]
# 2. Instalar `pyinstaller` mediante pip

# %%
! pip install pyinstaller

# %% [markdown]
# 3. Compilar el archio `graficador.py` con `pyinstaller`

# %%
! pyinstaller graficador.py
# Out:
# 55 INFO: PyInstaller: 3.5
# 56 INFO: Python: 3.7.3
# 66 INFO: Platform: Darwin-18.6.0-x86_64-i386-64bit
# 75 INFO: wrote /Users/dragon/Desktop/python-cenam/graficador.spec
# 81 INFO: UPX is not available.
# 83 INFO: Extending PYTHONPATH with paths
# ['/Users/dragon/Desktop/python-cenam', '/Users/dragon/Desktop/python-cenam']
# 83 INFO: checking Analysis
# 84 INFO: Building Analysis because Analysis-00.toc is non existent
# 84 INFO: Initializing module dependency graph...
# 88 INFO: Initializing module graph hooks...
# 89 INFO: Analyzing base_library.zip ...
# 4486 INFO: running Analysis Analysis-00.toc
# 4495 INFO: Caching module hooks...
# 4499 INFO: Analyzing /Users/dragon/Desktop/python-cenam/graficador.py
# 4608 INFO: Processing pre-find module path hook   distutils
# 6808 INFO: Processing pre-safe import module hook   six.moves
# 10104 INFO: Processing pre-safe import module hook   setuptools.extern.six.moves
# 10838 INFO: Processing pre-find module path hook   site
# ...
